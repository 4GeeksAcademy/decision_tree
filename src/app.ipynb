# %% [markdown]
# ### 0. Importing modules and data

# %%
import pandas as pd
from edastatmil_milser import edas_tatmil as EDA
import os

# %%
raw_df = pd.read_csv('../data/raw/Diabetes.csv')
raw_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### 1. Objective
#
# The goal is to predict based on diagnostic measures whether a patient has diabetes or not. Therefore, the target variable will be 'Outcome', where 0 indicates negative for diabetes and 1 indicates positive.

# %% [markdown]
# ### 2.Exploration and superficial cleaning

# %%
categorical, numerical = EDA.explore(raw_df)
# Out:
# Rows: 768
# Columns: 9
# +--------------------------+----------------+------------+-----------+---------------+
# |                          | Non-Null Count | Null Count | Data Type | Data Category |
# +--------------------------+----------------+------------+-----------+---------------+
# |       Pregnancies        |      768       |     0      |   int64   |   Numerical   |
# |         Glucose          |      768       |     0      |   int64   |   Numerical   |
# |      BloodPressure       |      768       |     0      |   int64   |   Numerical   |
# |      SkinThickness       |      768       |     0      |   int64   |   Numerical   |
# |         Insulin          |      768       |     0      |   int64   |   Numerical   |
# |           BMI            |      768       |     0      |  float64  |   Numerical   |
# | DiabetesPedigreeFunction |      768       |     0      |  float64  |   Numerical   |
# |           Age            |      768       |     0      |   int64   |   Numerical   |
# |         Outcome          |      768       |     0      |   int64   |   Numerical   |
# +--------------------------+----------------+------------+-----------+---------------+

# %% [markdown]
# It's a small dataset with no null values and all numeric columns, although our target variable is actually categorical and already factorized. All the information is relevant, so we don't eliminate any features a priori.
#
# ### 3. Univarite analysis

# %%
EDA.univariate_hist(['Pregnancies','Outcome'], raw_df)

# %%
aprox_H = (raw_df['Pregnancies'] != 0).sum()
aprox_V = (raw_df['Pregnancies'] == 0).sum()

print('N woman aprox:', aprox_H)
print('N men aprox:', aprox_V)
# Out:
# N woman aprox: 657
# N men aprox: 111

# %% [markdown]
# Given that we don't have the sex of the individual, adding the number of individuals who have had at least one pregnancy and those who have not had any can give us a rough idea of the number of men and women in the dataset. In this case, although there may be many women who have not had children, the difference is wide enough to make us wonder if training the model with this data could induce a bias that makes better predictions for women than for men..

# %%
EDA.univariate_histbox(['Glucose','BloodPressure','SkinThickness','Insulin','BMI','Age'], raw_df)

# %% [markdown]
# In general, the data seems fairly well grouped, although some outliers are observed that will need to be treated later.
#
# ### 4. Multivariate analysis

# %%
raw_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
list1 = ['Age', 'Glucose','Outcome']
list2 = ['Age', 'Insulin','Outcome']
list3 = ['Age', 'BMI','Outcome']
variable_lists = [list1,list2,list3]
EDA.multivariate_barplots(raw_df, variable_lists,y='mean',palette='Set2')

# %% [markdown]
# At all ages, a high BMI appears to indicate a higher probability of having diabetes. At all ages, people with diabetes have higher glucose levels. At older ages, people with diabetes have higher insulin levels.
#
# It is also observed that in the dataset, there are few older people who have diabetes.

# %%
_, df = EDA.correlation_matrix(raw_df, [],(10,7))

# %% [markdown]
# Of the 9 features we have, only blood pressure may not be determinative, so we will perform feature selection leaving 8 features.
#
# ### 5. Feature engineering
# #### 5.1 Outliers

# %%
features = [col for col in list(df.columns) if col != 'Outcome']

EDA.numerical_box(features, df)

# %%
clean_df = df.copy()
by_mean = ['Glucose', 'BloodPressure','BMI']
by_mode = ['Pregnancies','SkinThickness', 'Insulin', 'DiabetesPedigreeFunction', 'Age']
from edastatmil_milser.edas_tatmil import Do_enum

# %%
by_mean_outliers_list=[]
for col in by_mean:
    mean_outliers, clean_df = EDA.outliers_iqr(clean_df, col,2, Do=Do_enum.MEAN)
    by_mean_outliers_list.append(mean_outliers)
by_mean_outliers = pd.concat(by_mean_outliers_list, ignore_index=True)
# Out:
# 222.75 16.5
# 5 outliers have been treated by replacing them with the mean
# 116.0 26.0
# 37 outliers have been treated by replacing them with the mean
# 55.2 8.7
# 14 outliers have been treated by replacing them with the mean

# %%
by_mode_outliers_list=[]
for col in by_mode:
    mode_outliers, clean_df = EDA.outliers_iqr(clean_df, col,1.5, Do=Do_enum.MODE)
    by_mode_outliers_list.append(mode_outliers)
by_mode_outliers = pd.concat(by_mode_outliers_list, ignore_index=True)
# Out:
# 13.5 -6.5
# 4 outliers have been treated by replacing them with the mode
# 80.0 -48.0
# 1 outliers have been treated by replacing them with the mode
# 318.125 -190.875
# 34 outliers have been treated by replacing them with the mode
# 1.2 -0.32999999999999996
# 29 outliers have been treated by replacing them with the mode
# 66.5 -1.5
# 9 outliers have been treated by replacing them with the mode

# %%
outliers = pd.concat([by_mean_outliers,by_mode_outliers],ignore_index=True)

# %%
by_mean_outliers.to_csv('../data/processed/NonSplit/Outliers-Glu-Bold-BMI.csv')
by_mean_outliers.to_csv('../data/processed/NonSplit/Outliers-Preg-Skin-Ins-Diab-Age.csv')
outliers.to_csv('../data/processed/NonSplit/Outliers-All.csv')
clean_df.to_csv('../data/processed/Clean.csv')
df.to_csv('../data/processed/All.csv')

# %% [markdown]
# #### 5.2 Split data

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
predictors = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']
target = 'Outcome'
EDA.splitter('../data/processed/', predictors, target)
# Out:
# {'All_Xtrain':      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  334            1       95             60             18       58  23.9
#  139            5      105             72             29      325  36.9
#  485            0      135             68             42      250  42.3
#  547            4      131             68             21      166  33.1
#  18             1      103             30             38       83  43.3
#  ..           ...      ...            ...            ...      ...   ...
#  71             5      139             64             35      140  28.6
#  106            1       96            122              0        0  22.4
#  270           10      101             86             37        0  45.6
#  435            0      141              0              0        0  42.4
#  102            0      125             96              0        0  22.5
#
#       DiabetesPedigreeFunction  Age
#  334                     0.260   22
#  139                     0.159   28
#  485                     0.365   24
#  547                     0.160   28
#  18                      0.183   33
#  ..                        ...  ...
#  71                      0.411   26
#  106                     0.207   27
#  270                     1.136   38
#  435                     0.205   29
#  102                     0.262   21
#
#  [537 rows x 8 columns],
#  'All_Xtest':      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  668            6       98             58             33      190  34.0
#  324            2      112             75             32        0  35.7
#  624            2      108             64              0        0  30.8
#  690            8      107             80              0        0  24.6
#  473            7      136             90              0        0  29.9
#  ..           ...      ...            ...            ...      ...   ...
#  619            0      119              0              0        0  32.4
#  198            4      109             64             44       99  34.8
#  538            0      127             80             37      210  36.3
#  329            6      105             70             32       68  30.8
#  302            5       77             82             41       42  35.8
#
#       DiabetesPedigreeFunction  Age
#  668                     0.430   43
#  324                     0.148   21
#  624                     0.158   21
#  690                     0.856   34
#  473                     0.210   50
#  ..                        ...  ...
#  619                     0.141   24
#  198                     0.905   26
#  538                     0.804   23
#  329                     0.122   37
#  302                     0.156   35
#
#  [231 rows x 8 columns],
#  'All_ytrain': 334    0
#  139    0
#  485    1
#  547    0
#  18     0
#        ..
#  71     0
#  106    0
#  270    1
#  435    1
#  102    0
#  Name: Outcome, Length: 537, dtype: int64,
#  'All_ytest': 668    0
#  324    0
#  624    0
#  690    0
#  473    0
#        ..
#  619    1
#  198    1
#  538    0
#  329    0
#  302    0
#  Name: Outcome, Length: 231, dtype: int64,
#  'Clean_Xtrain':      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  334            1     95.0      60.000000             18       58  23.9
#  139            5    105.0      72.000000             29        0  36.9
#  485            0    135.0      68.000000             42      250  42.3
#  547            4    131.0      68.000000             21      166  33.1
#  18             1    103.0      30.000000             38       83  43.3
#  ..           ...      ...            ...            ...      ...   ...
#  71             5    139.0      64.000000             35      140  28.6
#  106            1     96.0      69.105469              0        0  22.4
#  270           10    101.0      86.000000             37        0  45.6
#  435            0    141.0      69.105469              0        0  42.4
#  102            0    125.0      96.000000              0        0  22.5
#
#       DiabetesPedigreeFunction  Age
#  334                     0.260   22
#  139                     0.159   28
#  485                     0.365   24
#  547                     0.160   28
#  18                      0.183   33
#  ..                        ...  ...
#  71                      0.411   26
#  106                     0.207   27
#  270                     1.136   38
#  435                     0.205   29
#  102                     0.262   21
#
#  [537 rows x 8 columns],
#  'Clean_Xtest':      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  668            6     98.0      58.000000             33      190  34.0
#  324            2    112.0      75.000000             32        0  35.7
#  624            2    108.0      64.000000              0        0  30.8
#  690            8    107.0      80.000000              0        0  24.6
#  473            7    136.0      90.000000              0        0  29.9
#  ..           ...      ...            ...            ...      ...   ...
#  619            0    119.0      69.105469              0        0  32.4
#  198            4    109.0      64.000000             44       99  34.8
#  538            0    127.0      80.000000             37      210  36.3
#  329            6    105.0      70.000000             32       68  30.8
#  302            5     77.0      82.000000             41       42  35.8
#
#       DiabetesPedigreeFunction  Age
#  668                     0.430   43
#  324                     0.148   21
#  624                     0.158   21
#  690                     0.856   34
#  473                     0.210   50
#  ..                        ...  ...
#  619                     0.141   24
#  198                     0.905   26
#  538                     0.804   23
#  329                     0.122   37
#  302                     0.156   35
#
#  [231 rows x 8 columns],
#  'Clean_ytrain': 334    0
#  139    0
#  485    1
#  547    0
#  18     0
#        ..
#  71     0
#  106    0
#  270    1
#  435    1
#  102    0
#  Name: Outcome, Length: 537, dtype: int64,
#  'Clean_ytest': 668    0
#  324    0
#  624    0
#  690    0
#  473    0
#        ..
#  619    1
#  198    1
#  538    0
#  329    0
#  302    0
#  Name: Outcome, Length: 231, dtype: int64}

# %% [markdown]
# #### 5.3 Normalize data

# %%
EDA.normalize('../data/processed/SplitData/',predictors,scaler='StandardScaler')
# Out:
# {'All_Xtest_norm':      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
#  0       0.523387 -0.739446      -0.444600       0.720042  0.956067  0.232733
#  1      -0.590921 -0.289349       0.329998       0.661122 -0.691043  0.433777
#  2      -0.590921 -0.417948      -0.171213      -1.224301 -0.691043 -0.145702
#  3       1.080541 -0.450098       0.557822      -1.224301 -0.691043 -0.878919
#  4       0.801964  0.482248       1.013468      -1.224301 -0.691043 -0.252136
#  ..           ...       ...            ...            ...       ...       ...
#  226    -1.148075 -0.064300      -3.087349      -1.224301 -0.691043  0.043516
#  227    -0.033767 -0.385798      -0.171213       1.368156  0.167188  0.327342
#  228    -1.148075  0.192899       0.557822       0.955720  1.129447  0.504733
#  229     0.523387 -0.514398       0.102175       0.661122 -0.101551 -0.145702
#  230     0.244810 -1.414593       0.648951       1.191398 -0.326945  0.445603
#
#       DiabetesPedigreeFunction       Age
#  0                   -0.152282  0.786051
#  1                   -1.077306 -1.059081
#  2                   -1.044503 -1.059081
#  3                    1.245094  0.031224
#  4                   -0.873932  1.373138
#  ..                        ...       ...
#  226                 -1.100267 -0.807472
#  227                  1.405825 -0.639733
#  228                  1.074522 -0.891341
#  229                 -1.162591  0.282833
#  230                 -1.051064  0.115094
#
#  [231 rows x 8 columns],
#  'Clean_Xtest_norm':      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
#  0       0.523387 -0.739446      -1.225349       0.779610  1.581933  0.193346
#  1      -0.590921 -0.289349       0.206911       0.717978 -0.735447  0.457024
#  2      -0.590921 -0.417948      -0.719845      -1.254260 -0.735447 -0.302991
#  3       1.080541 -0.450098       0.628164      -1.254260 -0.735447 -1.264643
#  4       0.801964  0.482248       1.470669      -1.254260 -0.735447 -0.442586
#  ..           ...       ...            ...            ...       ...       ...
#  226    -1.148075 -0.064300      -0.289707      -1.254260 -0.735447 -0.054823
#  227    -0.033767 -0.385798      -0.719845       1.457567  0.472030  0.317430
#  228    -1.148075  0.192899       0.628164       1.026140  1.825868  0.550087
#  229     0.523387 -0.514398      -0.214342       0.717978  0.093931 -0.302991
#  230     0.244810 -1.414593       0.796665       1.272669 -0.223184  0.472535
#
#       DiabetesPedigreeFunction       Age
#  0                   -0.002120  0.814729
#  1                   -1.133866 -1.058779
#  2                   -1.093733 -1.058779
#  3                    1.707540  0.048294
#  4                   -0.885042  1.410845
#  ..                        ...       ...
#  226                 -1.161959 -0.803301
#  227                  1.904191 -0.632982
#  228                  1.498849 -0.888460
#  229                 -1.238211  0.303772
#  230                 -1.101760  0.133453
#
#  [231 rows x 8 columns],
#  'All_Xtrain_norm':      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
#  0      -0.836294 -0.800051      -0.535764      -0.157146 -0.189732 -1.060153
#  1       0.390728 -0.490543       0.128044       0.553619  2.130203  0.646467
#  2      -1.143050  0.437979      -0.093226       1.393614  1.478536  1.355371
#  3       0.083972  0.314176      -0.093226       0.036699  0.748669  0.147609
#  4      -0.836294 -0.552445      -2.195284       1.135154  0.027491  1.486650
#  ..           ...       ...            ...            ...       ...       ...
#  532     0.390728  0.561782      -0.314495       0.941309  0.522758 -0.443144
#  533    -0.836294 -0.769100       2.893910      -1.320215 -0.693688 -1.257071
#  534     1.924505 -0.614346       0.902486       1.070539 -0.693688  1.788590
#  535    -1.143050  0.623683      -3.854804      -1.320215 -0.693688  1.368499
#  536    -1.143050  0.128472       1.455659      -1.320215 -0.693688 -1.243943
#
#       DiabetesPedigreeFunction       Age
#  0                   -0.614216 -0.948610
#  1                   -0.909738 -0.434667
#  2                   -0.306991 -0.777296
#  3                   -0.906812 -0.434667
#  4                   -0.839515 -0.006380
#  ..                        ...       ...
#  532                 -0.172397 -0.605981
#  533                 -0.769292 -0.520324
#  534                  1.948921  0.421906
#  535                 -0.775144 -0.349009
#  536                 -0.608364 -1.034268
#
#  [537 rows x 8 columns],
#  'Clean_Xtrain_norm':      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
#  0      -0.841271 -0.895858      -1.023597      -0.157146 -0.016353 -1.233997
#  1       0.442145 -0.563749      -0.009788       0.553619 -0.772052  0.708817
#  2      -1.162125  0.432578      -0.347724       1.393614  2.485270  1.515832
#  3       0.121291  0.299735      -0.347724       0.036699  1.390810  0.140918
#  4      -0.841271 -0.630171      -3.558121       1.135154  0.309379  1.665279
#  ..           ...       ...            ...            ...       ...       ...
#  532     0.442145  0.565422      -0.685661       0.941309  1.052048 -0.531595
#  533    -0.841271 -0.862647      -0.254330      -1.320215 -0.772052 -1.458167
#  534     2.046415 -0.696592       1.172990       1.070539 -0.772052  2.009008
#  535    -1.162125  0.631844      -0.254330      -1.320215 -0.772052  1.530777
#  536    -1.162125  0.100469       2.017831      -1.320215 -0.772052 -1.443223
#
#       DiabetesPedigreeFunction       Age
#  0                   -0.650415 -0.958862
#  1                   -1.060894 -0.403205
#  2                   -0.223679 -0.773643
#  3                   -1.056830 -0.403205
#  4                   -0.963354  0.059843
#  ..                        ...       ...
#  532                 -0.036729 -0.588424
#  533                 -0.865815 -0.495815
#  534                  2.909778  0.522890
#  535                 -0.873943 -0.310595
#  536                 -0.642287 -1.051472
#
#  [537 rows x 8 columns]}

# %% [markdown]
# #### 5.4 Selection

# %%
Xtrain_All = pd.read_csv('../data/processed/SplitData/NormData/All_Xtrain_norm.csv')
ytrain_All = pd.read_csv('../data/processed/SplitData/All_ytrain.csv')

Xtrain_Clean = pd.read_csv('../data/processed/SplitData/NormData/Clean_Xtrain_norm.csv')
ytrain_Clean = pd.read_csv('../data/processed/SplitData/Clean_ytrain.csv')

# %%
EDA.feature_sel(Xtrain_All,ytrain_All,k=7,file_name='All_Xtrain', method='SelectKBest', test='mutual_info_regression')

EDA.feature_sel(Xtrain_Clean,ytrain_Clean,k=7,file_name='Clean_Xtrain', method='SelectKBest', test='mutual_info_regression')
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (     Pregnancies   Glucose  SkinThickness   Insulin       BMI  \
#  0      -0.841271 -0.895858      -0.157146 -0.016353 -1.233997
#  1       0.442145 -0.563749       0.553619 -0.772052  0.708817
#  2      -1.162125  0.432578       1.393614  2.485270  1.515832
#  3       0.121291  0.299735       0.036699  1.390810  0.140918
#  4      -0.841271 -0.630171       1.135154  0.309379  1.665279
#  ..           ...       ...            ...       ...       ...
#  532     0.442145  0.565422       0.941309  1.052048 -0.531595
#  533    -0.841271 -0.862647      -1.320215 -0.772052 -1.458167
#  534     2.046415 -0.696592       1.070539 -0.772052  2.009008
#  535    -1.162125  0.631844      -1.320215 -0.772052  1.530777
#  536    -1.162125  0.100469      -1.320215 -0.772052 -1.443223
#
#       DiabetesPedigreeFunction       Age
#  0                   -0.650415 -0.958862
#  1                   -1.060894 -0.403205
#  2                   -0.223679 -0.773643
#  3                   -1.056830 -0.403205
#  4                   -0.963354  0.059843
#  ..                        ...       ...
#  532                 -0.036729 -0.588424
#  533                 -0.865815 -0.495815
#  534                  2.909778  0.522890
#  535                 -0.873943 -0.310595
#  536                 -0.642287 -1.051472
#
#  [537 rows x 7 columns],
#  ['Pregnancies',
#   'Glucose',
#   'SkinThickness',
#   'Insulin',
#   'BMI',
#   'DiabetesPedigreeFunction',
#   'Age'])

# %%
Xtrain_All_Sel = pd.read_csv('../data/processed/SplitData/FeatureSel/All_Xtrain_FeatureSel.csv')

Xtrain_Clean_Sel = pd.read_csv('../data/processed/SplitData/FeatureSel/Clean_Xtrain_FeatureSel.csv')

# %%
Xtrain_All_Sel.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
Xtrain_Clean_Sel.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# Indeed, the feature selection removes the blood pressure column, as suspected.
#
# ### 6. Decission Tree Model
# #### 6.1 Init and train

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn import tree
from pickle import dump
from sklearn.metrics import mean_squared_error

All_model = DecisionTreeRegressor(random_state = 42)
All_model.fit(Xtrain_All_Sel, ytrain_All )
dump(All_model, open("../data/processed/Models/All_decision_tree_regressor_default_42.sav", "wb"))

# %%
fig = plt.figure(figsize=(15,15))
tree.plot_tree(All_model, feature_names = list(Xtrain_All_Sel.columns), class_names = ["0", "1"], filled = True)
# Out:
# [Text(0.6164362980769231, 0.9705882352941176, 'Glucose <= 1.042\nsquared_error = 0.228\nsamples = 537\nvalue = 0.35'),
#  Text(0.3290264423076923, 0.9117647058823529, 'Age <= -0.392\nsquared_error = 0.191\nsamples = 454\nvalue = 0.258'),
#  Text(0.1856971153846154, 0.8529411764705882, 'Glucose <= 0.206\nsquared_error = 0.11\nsamples = 238\nvalue = 0.126'),
#  Text(0.0829326923076923, 0.7941176470588235, 'BMI <= 2.248\nsquared_error = 0.059\nsamples = 192\nvalue = 0.062'),
#  Text(0.0733173076923077, 0.7352941176470589, 'BMI <= -0.076\nsquared_error = 0.05\nsamples = 190\nvalue = 0.053'),
#  Text(0.019230769230769232, 0.6764705882352942, 'DiabetesPedigreeFunction <= 0.591\nsquared_error = 0.009\nsamples = 111\nvalue = 0.009'),
#  Text(0.009615384615384616, 0.6176470588235294, 'squared_error = 0.0\nsamples = 96\nvalue = 0.0'),
#  Text(0.028846153846153848, 0.6176470588235294, 'DiabetesPedigreeFunction <= 0.666\nsquared_error = 0.062\nsamples = 15\nvalue = 0.067'),
#  Text(0.019230769230769232, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.038461538461538464, 0.5588235294117647, 'squared_error = 0.0\nsamples = 14\nvalue = 0.0'),
#  Text(0.12740384615384615, 0.6764705882352942, 'Insulin <= -0.615\nsquared_error = 0.101\nsamples = 79\nvalue = 0.114'),
#  Text(0.08173076923076923, 0.6176470588235294, 'Glucose <= -0.289\nsquared_error = 0.192\nsamples = 27\nvalue = 0.259'),
#  Text(0.057692307692307696, 0.5588235294117647, 'SkinThickness <= 1.297\nsquared_error = 0.052\nsamples = 18\nvalue = 0.056'),
#  Text(0.04807692307692308, 0.5, 'squared_error = 0.0\nsamples = 17\nvalue = 0.0'),
#  Text(0.0673076923076923, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.10576923076923077, 0.5588235294117647, 'BMI <= 0.712\nsquared_error = 0.222\nsamples = 9\nvalue = 0.667'),
#  Text(0.08653846153846154, 0.5, 'BMI <= -0.003\nsquared_error = 0.139\nsamples = 6\nvalue = 0.833'),
#  Text(0.07692307692307693, 0.4411764705882353, 'DiabetesPedigreeFunction <= -0.866\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.0673076923076923, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.08653846153846154, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.09615384615384616, 0.4411764705882353, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.125, 0.5, 'Age <= -0.991\nsquared_error = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(0.11538461538461539, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.1346153846153846, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.17307692307692307, 0.6176470588235294, 'Pregnancies <= 0.237\nsquared_error = 0.037\nsamples = 52\nvalue = 0.038'),
#  Text(0.15384615384615385, 0.5588235294117647, 'DiabetesPedigreeFunction <= 0.496\nsquared_error = 0.02\nsamples = 49\nvalue = 0.02'),
#  Text(0.14423076923076922, 0.5, 'squared_error = 0.0\nsamples = 43\nvalue = 0.0'),
#  Text(0.16346153846153846, 0.5, 'DiabetesPedigreeFunction <= 0.603\nsquared_error = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(0.15384615384615385, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.17307692307692307, 0.4411764705882353, 'squared_error = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(0.19230769230769232, 0.5588235294117647, 'Age <= -0.563\nsquared_error = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(0.18269230769230768, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.20192307692307693, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.09254807692307693, 0.7352941176470589, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.28846153846153844, 0.7941176470588235, 'Insulin <= 1.626\nsquared_error = 0.238\nsamples = 46\nvalue = 0.391'),
#  Text(0.27884615384615385, 0.7352941176470589, 'BMI <= -0.266\nsquared_error = 0.248\nsamples = 40\nvalue = 0.45'),
#  Text(0.2403846153846154, 0.6764705882352942, 'Age <= -0.477\nsquared_error = 0.168\nsamples = 14\nvalue = 0.214'),
#  Text(0.22115384615384615, 0.6176470588235294, 'Pregnancies <= -0.376\nsquared_error = 0.083\nsamples = 11\nvalue = 0.091'),
#  Text(0.21153846153846154, 0.5588235294117647, 'squared_error = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(0.23076923076923078, 0.5588235294117647, 'SkinThickness <= -0.189\nsquared_error = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(0.22115384615384615, 0.5, 'Glucose <= 0.423\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.21153846153846154, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.23076923076923078, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.2403846153846154, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.25961538461538464, 0.6176470588235294, 'DiabetesPedigreeFunction <= -0.389\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.25, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.2692307692307692, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.3173076923076923, 0.6764705882352942, 'DiabetesPedigreeFunction <= -0.465\nsquared_error = 0.244\nsamples = 26\nvalue = 0.577'),
#  Text(0.2980769230769231, 0.6176470588235294, 'SkinThickness <= 1.2\nsquared_error = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(0.28846153846153844, 0.5588235294117647, 'squared_error = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(0.3076923076923077, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.33653846153846156, 0.6176470588235294, 'Pregnancies <= 0.544\nsquared_error = 0.21\nsamples = 20\nvalue = 0.7'),
#  Text(0.3269230769230769, 0.5588235294117647, 'Age <= -0.734\nsquared_error = 0.173\nsamples = 18\nvalue = 0.778'),
#  Text(0.3173076923076923, 0.5, 'BMI <= 1.086\nsquared_error = 0.24\nsamples = 10\nvalue = 0.6'),
#  Text(0.3076923076923077, 0.4411764705882353, 'DiabetesPedigreeFunction <= 0.04\nsquared_error = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(0.2980769230769231, 0.38235294117647056, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.3173076923076923, 0.38235294117647056, 'Glucose <= 0.345\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.3076923076923077, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.3269230769230769, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.3269230769230769, 0.4411764705882353, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.33653846153846156, 0.5, 'squared_error = 0.0\nsamples = 8\nvalue = 1.0'),
#  Text(0.34615384615384615, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.2980769230769231, 0.7352941176470589, 'squared_error = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(0.4723557692307692, 0.8529411764705882, 'BMI <= -0.66\nsquared_error = 0.241\nsamples = 216\nvalue = 0.403'),
#  Text(0.375, 0.7941176470588235, 'Age <= -0.306\nsquared_error = 0.065\nsamples = 43\nvalue = 0.07'),
#  Text(0.36538461538461536, 0.7352941176470589, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.38461538461538464, 0.7352941176470589, 'BMI <= -2.931\nsquared_error = 0.045\nsamples = 42\nvalue = 0.048'),
#  Text(0.36538461538461536, 0.6764705882352942, 'Age <= 2.435\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.3557692307692308, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.375, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.40384615384615385, 0.6764705882352942, 'Glucose <= 0.376\nsquared_error = 0.024\nsamples = 40\nvalue = 0.025'),
#  Text(0.3942307692307692, 0.6176470588235294, 'squared_error = 0.0\nsamples = 35\nvalue = 0.0'),
#  Text(0.41346153846153844, 0.6176470588235294, 'Age <= 2.092\nsquared_error = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(0.40384615384615385, 0.5588235294117647, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.4230769230769231, 0.5588235294117647, 'SkinThickness <= -0.254\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.41346153846153844, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.4326923076923077, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.5697115384615384, 0.7941176470588235, 'Glucose <= -0.816\nsquared_error = 0.25\nsamples = 173\nvalue = 0.486'),
#  Text(0.4326923076923077, 0.7352941176470589, 'Glucose <= -2.858\nsquared_error = 0.13\nsamples = 26\nvalue = 0.154'),
#  Text(0.4230769230769231, 0.6764705882352942, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.4423076923076923, 0.6764705882352942, 'Pregnancies <= 1.771\nsquared_error = 0.076\nsamples = 24\nvalue = 0.083'),
#  Text(0.4326923076923077, 0.6176470588235294, 'squared_error = 0.0\nsamples = 18\nvalue = 0.0'),
#  Text(0.4519230769230769, 0.6176470588235294, 'DiabetesPedigreeFunction <= -0.524\nsquared_error = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(0.4423076923076923, 0.5588235294117647, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.46153846153846156, 0.5588235294117647, 'BMI <= 0.41\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.4519230769230769, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.47115384615384615, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7067307692307693, 0.7352941176470589, 'DiabetesPedigreeFunction <= 0.17\nsquared_error = 0.248\nsamples = 147\nvalue = 0.544'),
#  Text(0.6057692307692307, 0.6764705882352942, 'SkinThickness <= 0.392\nsquared_error = 0.249\nsamples = 99\nvalue = 0.465'),
#  Text(0.5480769230769231, 0.6176470588235294, 'SkinThickness <= -0.06\nsquared_error = 0.246\nsamples = 57\nvalue = 0.561'),
#  Text(0.5192307692307693, 0.5588235294117647, 'BMI <= -0.417\nsquared_error = 0.25\nsamples = 48\nvalue = 0.5'),
#  Text(0.49038461538461536, 0.5, 'DiabetesPedigreeFunction <= -0.635\nsquared_error = 0.16\nsamples = 10\nvalue = 0.2'),
#  Text(0.4807692307692308, 0.4411764705882353, 'squared_error = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(0.5, 0.4411764705882353, 'DiabetesPedigreeFunction <= -0.112\nsquared_error = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(0.49038461538461536, 0.38235294117647056, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.5096153846153846, 0.38235294117647056, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.5480769230769231, 0.5, 'Pregnancies <= 2.078\nsquared_error = 0.244\nsamples = 38\nvalue = 0.579'),
#  Text(0.5384615384615384, 0.4411764705882353, 'Insulin <= -0.02\nsquared_error = 0.233\nsamples = 35\nvalue = 0.629'),
#  Text(0.5288461538461539, 0.38235294117647056, 'Age <= 0.979\nsquared_error = 0.222\nsamples = 33\nvalue = 0.667'),
#  Text(0.5096153846153846, 0.3235294117647059, 'Glucose <= -0.15\nsquared_error = 0.16\nsamples = 20\nvalue = 0.8'),
#  Text(0.5, 0.2647058823529412, 'squared_error = 0.0\nsamples = 9\nvalue = 1.0'),
#  Text(0.5192307692307693, 0.2647058823529412, 'Glucose <= 0.067\nsquared_error = 0.231\nsamples = 11\nvalue = 0.636'),
#  Text(0.5096153846153846, 0.20588235294117646, 'BMI <= -0.2\nsquared_error = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(0.5, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.5192307692307693, 0.14705882352941177, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.5288461538461539, 0.20588235294117646, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.5480769230769231, 0.3235294117647059, 'Glucose <= -0.243\nsquared_error = 0.249\nsamples = 13\nvalue = 0.462'),
#  Text(0.5384615384615384, 0.2647058823529412, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.5576923076923077, 0.2647058823529412, 'BMI <= 0.653\nsquared_error = 0.24\nsamples = 10\nvalue = 0.6'),
#  Text(0.5480769230769231, 0.20588235294117646, 'Age <= 1.064\nsquared_error = 0.188\nsamples = 8\nvalue = 0.75'),
#  Text(0.5384615384615384, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.5576923076923077, 0.14705882352941177, 'SkinThickness <= -0.836\nsquared_error = 0.122\nsamples = 7\nvalue = 0.857'),
#  Text(0.5480769230769231, 0.08823529411764706, 'squared_error = 0.0\nsamples = 5\nvalue = 1.0'),
#  Text(0.5673076923076923, 0.08823529411764706, 'SkinThickness <= -0.254\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.5576923076923077, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.5769230769230769, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.5673076923076923, 0.20588235294117646, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.5480769230769231, 0.38235294117647056, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.5576923076923077, 0.4411764705882353, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.5769230769230769, 0.5588235294117647, 'Glucose <= 0.763\nsquared_error = 0.099\nsamples = 9\nvalue = 0.889'),
#  Text(0.5673076923076923, 0.5, 'squared_error = 0.0\nsamples = 8\nvalue = 1.0'),
#  Text(0.5865384615384616, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.6634615384615384, 0.6176470588235294, 'Insulin <= 0.253\nsquared_error = 0.222\nsamples = 42\nvalue = 0.333'),
#  Text(0.6153846153846154, 0.5588235294117647, 'BMI <= 0.187\nsquared_error = 0.151\nsamples = 27\nvalue = 0.185'),
#  Text(0.6057692307692307, 0.5, 'squared_error = 0.0\nsamples = 10\nvalue = 0.0'),
#  Text(0.625, 0.5, 'DiabetesPedigreeFunction <= -0.677\nsquared_error = 0.208\nsamples = 17\nvalue = 0.294'),
#  Text(0.6153846153846154, 0.4411764705882353, 'squared_error = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(0.6346153846153846, 0.4411764705882353, 'SkinThickness <= 0.683\nsquared_error = 0.248\nsamples = 11\nvalue = 0.455'),
#  Text(0.625, 0.38235294117647056, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.6442307692307693, 0.38235294117647056, 'BMI <= 0.896\nsquared_error = 0.234\nsamples = 8\nvalue = 0.625'),
#  Text(0.6346153846153846, 0.3235294117647059, 'BMI <= 0.469\nsquared_error = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(0.625, 0.2647058823529412, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.6442307692307693, 0.2647058823529412, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.6538461538461539, 0.3235294117647059, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.7115384615384616, 0.5588235294117647, 'Age <= 0.807\nsquared_error = 0.24\nsamples = 15\nvalue = 0.6'),
#  Text(0.7019230769230769, 0.5, 'Glucose <= 0.794\nsquared_error = 0.248\nsamples = 11\nvalue = 0.455'),
#  Text(0.6923076923076923, 0.4411764705882353, 'Glucose <= 0.067\nsquared_error = 0.222\nsamples = 9\nvalue = 0.333'),
#  Text(0.6826923076923077, 0.38235294117647056, 'DiabetesPedigreeFunction <= -0.25\nsquared_error = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(0.6730769230769231, 0.3235294117647059, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.6923076923076923, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.7019230769230769, 0.38235294117647056, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.7115384615384616, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.7211538461538461, 0.5, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.8076923076923077, 0.6764705882352942, 'BMI <= -0.049\nsquared_error = 0.207\nsamples = 48\nvalue = 0.708'),
#  Text(0.7692307692307693, 0.6176470588235294, 'BMI <= -0.378\nsquared_error = 0.249\nsamples = 17\nvalue = 0.471'),
#  Text(0.75, 0.5588235294117647, 'Glucose <= 0.345\nsquared_error = 0.21\nsamples = 10\nvalue = 0.7'),
#  Text(0.7403846153846154, 0.5, 'Pregnancies <= -0.53\nsquared_error = 0.109\nsamples = 8\nvalue = 0.875'),
#  Text(0.7307692307692307, 0.4411764705882353, 'BMI <= -0.574\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.7211538461538461, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7403846153846154, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.75, 0.4411764705882353, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.7596153846153846, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.7884615384615384, 0.5588235294117647, 'Age <= 1.45\nsquared_error = 0.122\nsamples = 7\nvalue = 0.143'),
#  Text(0.7788461538461539, 0.5, 'squared_error = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(0.7980769230769231, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.8461538461538461, 0.6176470588235294, 'DiabetesPedigreeFunction <= 1.987\nsquared_error = 0.135\nsamples = 31\nvalue = 0.839'),
#  Text(0.8269230769230769, 0.5588235294117647, 'SkinThickness <= 2.201\nsquared_error = 0.071\nsamples = 26\nvalue = 0.923'),
#  Text(0.8173076923076923, 0.5, 'SkinThickness <= -0.577\nsquared_error = 0.038\nsamples = 25\nvalue = 0.96'),
#  Text(0.8076923076923077, 0.4411764705882353, 'Glucose <= -0.073\nsquared_error = 0.16\nsamples = 5\nvalue = 0.8'),
#  Text(0.7980769230769231, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8173076923076923, 0.38235294117647056, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.8269230769230769, 0.4411764705882353, 'squared_error = 0.0\nsamples = 20\nvalue = 1.0'),
#  Text(0.8365384615384616, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8653846153846154, 0.5588235294117647, 'Age <= 0.251\nsquared_error = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(0.8557692307692307, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.875, 0.5, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.9038461538461539, 0.9117647058823529, 'BMI <= -0.43\nsquared_error = 0.124\nsamples = 83\nvalue = 0.855'),
#  Text(0.8557692307692307, 0.8529411764705882, 'BMI <= -0.87\nsquared_error = 0.243\nsamples = 12\nvalue = 0.583'),
#  Text(0.8461538461538461, 0.7941176470588235, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.8653846153846154, 0.7941176470588235, 'Age <= 1.664\nsquared_error = 0.234\nsamples = 8\nvalue = 0.375'),
#  Text(0.8557692307692307, 0.7352941176470589, 'Age <= -0.649\nsquared_error = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(0.8461538461538461, 0.6764705882352942, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.8653846153846154, 0.6764705882352942, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.875, 0.7352941176470589, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.9519230769230769, 0.8529411764705882, 'DiabetesPedigreeFunction <= 2.802\nsquared_error = 0.089\nsamples = 71\nvalue = 0.901'),
#  Text(0.9230769230769231, 0.7941176470588235, 'Glucose <= 1.382\nsquared_error = 0.07\nsamples = 66\nvalue = 0.924'),
#  Text(0.8942307692307693, 0.7352941176470589, 'Glucose <= 1.351\nsquared_error = 0.16\nsamples = 20\nvalue = 0.8'),
#  Text(0.8846153846153846, 0.6764705882352942, 'Age <= -0.734\nsquared_error = 0.099\nsamples = 18\nvalue = 0.889'),
#  Text(0.875, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8942307692307693, 0.6176470588235294, 'DiabetesPedigreeFunction <= -0.962\nsquared_error = 0.055\nsamples = 17\nvalue = 0.941'),
#  Text(0.8846153846153846, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9038461538461539, 0.5588235294117647, 'squared_error = 0.0\nsamples = 16\nvalue = 1.0'),
#  Text(0.9038461538461539, 0.6764705882352942, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.9519230769230769, 0.7352941176470589, 'Age <= -0.563\nsquared_error = 0.021\nsamples = 46\nvalue = 0.978'),
#  Text(0.9423076923076923, 0.6764705882352942, 'SkinThickness <= 0.36\nsquared_error = 0.099\nsamples = 9\nvalue = 0.889'),
#  Text(0.9326923076923077, 0.6176470588235294, 'BMI <= 0.134\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.9230769230769231, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.9423076923076923, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9519230769230769, 0.6176470588235294, 'squared_error = 0.0\nsamples = 7\nvalue = 1.0'),
#  Text(0.9615384615384616, 0.6764705882352942, 'squared_error = 0.0\nsamples = 37\nvalue = 1.0'),
#  Text(0.9807692307692307, 0.7941176470588235, 'Glucose <= 1.877\nsquared_error = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(0.9711538461538461, 0.7352941176470589, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.9903846153846154, 0.7352941176470589, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0')]

# %%
Clean_model = DecisionTreeRegressor(random_state = 42)
Clean_model.fit(Xtrain_Clean_Sel, ytrain_Clean )
dump(Clean_model, open("../data/processed/Models/Clean_decision_tree_regressor_default_42.sav", "wb"))

tree.plot_tree(Clean_model, feature_names = list(Xtrain_Clean_Sel.columns), class_names = ["0", "1"], filled = True)
# Out:
# [Text(0.6491522082018928, 0.9705882352941176, 'Glucose <= 1.08\nsquared_error = 0.228\nsamples = 537\nvalue = 0.35'),
#  Text(0.4055599369085173, 0.9117647058823529, 'Age <= -0.357\nsquared_error = 0.191\nsamples = 454\nvalue = 0.258'),
#  Text(0.22870662460567823, 0.8529411764705882, 'Glucose <= 0.183\nsquared_error = 0.111\nsamples = 245\nvalue = 0.127'),
#  Text(0.10094637223974763, 0.7941176470588235, 'BMI <= 2.532\nsquared_error = 0.058\nsamples = 195\nvalue = 0.062'),
#  Text(0.08832807570977919, 0.7352941176470589, 'BMI <= -0.113\nsquared_error = 0.049\nsamples = 193\nvalue = 0.052'),
#  Text(0.025236593059936908, 0.6764705882352942, 'DiabetesPedigreeFunction <= 1.024\nsquared_error = 0.009\nsamples = 110\nvalue = 0.009'),
#  Text(0.012618296529968454, 0.6176470588235294, 'squared_error = 0.0\nsamples = 96\nvalue = 0.0'),
#  Text(0.03785488958990536, 0.6176470588235294, 'DiabetesPedigreeFunction <= 1.128\nsquared_error = 0.066\nsamples = 14\nvalue = 0.071'),
#  Text(0.025236593059936908, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.050473186119873815, 0.5588235294117647, 'squared_error = 0.0\nsamples = 13\nvalue = 0.0'),
#  Text(0.15141955835962145, 0.6764705882352942, 'Insulin <= -0.655\nsquared_error = 0.097\nsamples = 83\nvalue = 0.108'),
#  Text(0.10094637223974763, 0.6176470588235294, 'Glucose <= -0.348\nsquared_error = 0.171\nsamples = 32\nvalue = 0.219'),
#  Text(0.07570977917981073, 0.5588235294117647, 'SkinThickness <= 1.297\nsquared_error = 0.048\nsamples = 20\nvalue = 0.05'),
#  Text(0.06309148264984227, 0.5, 'squared_error = 0.0\nsamples = 19\nvalue = 0.0'),
#  Text(0.08832807570977919, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.12618296529968454, 0.5588235294117647, 'Glucose <= -0.281\nsquared_error = 0.25\nsamples = 12\nvalue = 0.5'),
#  Text(0.11356466876971609, 0.5, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.138801261829653, 0.5, 'BMI <= -0.001\nsquared_error = 0.222\nsamples = 9\nvalue = 0.333'),
#  Text(0.12618296529968454, 0.4411764705882353, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.15141955835962145, 0.4411764705882353, 'SkinThickness <= -0.642\nsquared_error = 0.25\nsamples = 6\nvalue = 0.5'),
#  Text(0.138801261829653, 0.38235294117647056, 'DiabetesPedigreeFunction <= 1.538\nsquared_error = 0.188\nsamples = 4\nvalue = 0.75'),
#  Text(0.12618296529968454, 0.3235294117647059, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.15141955835962145, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.1640378548895899, 0.38235294117647056, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.20189274447949526, 0.6176470588235294, 'Pregnancies <= 0.282\nsquared_error = 0.038\nsamples = 51\nvalue = 0.039'),
#  Text(0.17665615141955837, 0.5588235294117647, 'DiabetesPedigreeFunction <= 0.892\nsquared_error = 0.02\nsamples = 49\nvalue = 0.02'),
#  Text(0.1640378548895899, 0.5, 'squared_error = 0.0\nsamples = 43\nvalue = 0.0'),
#  Text(0.1892744479495268, 0.5, 'DiabetesPedigreeFunction <= 1.04\nsquared_error = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(0.17665615141955837, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.20189274447949526, 0.4411764705882353, 'squared_error = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(0.22712933753943218, 0.5588235294117647, 'Age <= -0.542\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.21451104100946372, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.23974763406940064, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.11356466876971609, 0.7352941176470589, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.35646687697160884, 0.7941176470588235, 'BMI <= -0.33\nsquared_error = 0.236\nsamples = 50\nvalue = 0.38'),
#  Text(0.3028391167192429, 0.7352941176470589, 'Age <= -0.45\nsquared_error = 0.139\nsamples = 18\nvalue = 0.167'),
#  Text(0.277602523659306, 0.6764705882352942, 'Pregnancies <= -0.36\nsquared_error = 0.062\nsamples = 15\nvalue = 0.067'),
#  Text(0.26498422712933756, 0.6176470588235294, 'squared_error = 0.0\nsamples = 10\nvalue = 0.0'),
#  Text(0.2902208201892745, 0.6176470588235294, 'Pregnancies <= 0.121\nsquared_error = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(0.277602523659306, 0.5588235294117647, 'Glucose <= 0.416\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.26498422712933756, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.2902208201892745, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.3028391167192429, 0.5588235294117647, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.3280757097791798, 0.6764705882352942, 'DiabetesPedigreeFunction <= -0.337\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.31545741324921134, 0.6176470588235294, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.34069400630914826, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.41009463722397477, 0.7352941176470589, 'Pregnancies <= -1.002\nsquared_error = 0.25\nsamples = 32\nvalue = 0.5'),
#  Text(0.3785488958990536, 0.6764705882352942, 'BMI <= 0.238\nsquared_error = 0.198\nsamples = 11\nvalue = 0.727'),
#  Text(0.3659305993690852, 0.6176470588235294, 'Insulin <= 0.075\nsquared_error = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(0.35331230283911674, 0.5588235294117647, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.3785488958990536, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.3911671924290221, 0.6176470588235294, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.4416403785488959, 0.6764705882352942, 'BMI <= 0.074\nsquared_error = 0.236\nsamples = 21\nvalue = 0.381'),
#  Text(0.416403785488959, 0.6176470588235294, 'Age <= -0.774\nsquared_error = 0.222\nsamples = 9\nvalue = 0.667'),
#  Text(0.4037854889589905, 0.5588235294117647, 'Pregnancies <= -0.039\nsquared_error = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(0.3911671924290221, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.416403785488959, 0.5, 'Pregnancies <= 0.282\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.4037854889589905, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.42902208201892744, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.42902208201892744, 0.5588235294117647, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.4668769716088328, 0.6176470588235294, 'BMI <= 1.217\nsquared_error = 0.139\nsamples = 12\nvalue = 0.167'),
#  Text(0.45425867507886436, 0.5588235294117647, 'squared_error = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(0.4794952681388013, 0.5588235294117647, 'Glucose <= 0.682\nsquared_error = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(0.4668769716088328, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.4921135646687697, 0.5, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.5824132492113565, 0.8529411764705882, 'BMI <= -0.868\nsquared_error = 0.242\nsamples = 209\nvalue = 0.411'),
#  Text(0.5047318611987381, 0.7941176470588235, 'Age <= 2.421\nsquared_error = 0.029\nsamples = 34\nvalue = 0.029'),
#  Text(0.4921135646687697, 0.7352941176470589, 'squared_error = 0.0\nsamples = 32\nvalue = 0.0'),
#  Text(0.5173501577287066, 0.7352941176470589, 'BMI <= -1.159\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.5047318611987381, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.5299684542586751, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.6600946372239748, 0.7941176470588235, 'Glucose <= -0.746\nsquared_error = 0.25\nsamples = 175\nvalue = 0.486'),
#  Text(0.580441640378549, 0.7352941176470589, 'Insulin <= 0.361\nsquared_error = 0.129\nsamples = 33\nvalue = 0.152'),
#  Text(0.555205047318612, 0.6764705882352942, 'Age <= 1.912\nsquared_error = 0.09\nsamples = 30\nvalue = 0.1'),
#  Text(0.5425867507886435, 0.6176470588235294, 'BMI <= 0.014\nsquared_error = 0.064\nsamples = 29\nvalue = 0.069'),
#  Text(0.5299684542586751, 0.5588235294117647, 'Pregnancies <= 2.207\nsquared_error = 0.16\nsamples = 10\nvalue = 0.2'),
#  Text(0.5173501577287066, 0.5, 'DiabetesPedigreeFunction <= -0.856\nsquared_error = 0.099\nsamples = 9\nvalue = 0.111'),
#  Text(0.5047318611987381, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.5299684542586751, 0.4411764705882353, 'squared_error = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(0.5425867507886435, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.555205047318612, 0.5588235294117647, 'squared_error = 0.0\nsamples = 19\nvalue = 0.0'),
#  Text(0.5678233438485805, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.6056782334384858, 0.6764705882352942, 'Age <= 1.125\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.5930599369085173, 0.6176470588235294, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.6182965299684543, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7397476340694006, 0.7352941176470589, 'DiabetesPedigreeFunction <= 0.439\nsquared_error = 0.246\nsamples = 142\nvalue = 0.563'),
#  Text(0.6750788643533123, 0.6764705882352942, 'Pregnancies <= 2.207\nsquared_error = 0.25\nsamples = 100\nvalue = 0.49'),
#  Text(0.6624605678233438, 0.6176470588235294, 'Age <= 2.421\nsquared_error = 0.25\nsamples = 95\nvalue = 0.516'),
#  Text(0.6498422712933754, 0.5588235294117647, 'SkinThickness <= 1.587\nsquared_error = 0.249\nsamples = 91\nvalue = 0.538'),
#  Text(0.637223974763407, 0.5, 'SkinThickness <= 0.392\nsquared_error = 0.249\nsamples = 88\nvalue = 0.523'),
#  Text(0.555205047318612, 0.4411764705882353, 'SkinThickness <= -0.06\nsquared_error = 0.239\nsamples = 53\nvalue = 0.604'),
#  Text(0.5078864353312302, 0.38235294117647056, 'BMI <= -0.502\nsquared_error = 0.249\nsamples = 43\nvalue = 0.535'),
#  Text(0.45110410094637227, 0.3235294117647059, 'DiabetesPedigreeFunction <= -0.665\nsquared_error = 0.16\nsamples = 10\nvalue = 0.2'),
#  Text(0.4384858044164038, 0.2647058823529412, 'squared_error = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(0.4637223974763407, 0.2647058823529412, 'SkinThickness <= -0.933\nsquared_error = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(0.45110410094637227, 0.20588235294117646, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.47634069400630913, 0.20588235294117646, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.5646687697160884, 0.3235294117647059, 'SkinThickness <= -0.448\nsquared_error = 0.231\nsamples = 33\nvalue = 0.636'),
#  Text(0.5520504731861199, 0.2647058823529412, 'BMI <= 0.283\nsquared_error = 0.219\nsamples = 31\nvalue = 0.677'),
#  Text(0.501577287066246, 0.20588235294117646, 'Pregnancies <= -0.36\nsquared_error = 0.145\nsamples = 17\nvalue = 0.824'),
#  Text(0.47634069400630913, 0.14705882352941177, 'Age <= 1.31\nsquared_error = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(0.4637223974763407, 0.08823529411764706, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.4889589905362776, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.526813880126183, 0.14705882352941177, 'Pregnancies <= 1.726\nsquared_error = 0.066\nsamples = 14\nvalue = 0.929'),
#  Text(0.5141955835962145, 0.08823529411764706, 'squared_error = 0.0\nsamples = 12\nvalue = 1.0'),
#  Text(0.5394321766561514, 0.08823529411764706, 'Age <= 0.847\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.526813880126183, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.5520504731861199, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.6025236593059937, 0.20588235294117646, 'Pregnancies <= -0.039\nsquared_error = 0.25\nsamples = 14\nvalue = 0.5'),
#  Text(0.5772870662460567, 0.14705882352941177, 'Glucose <= 0.715\nsquared_error = 0.16\nsamples = 5\nvalue = 0.8'),
#  Text(0.5646687697160884, 0.08823529411764706, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.5899053627760252, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.6277602523659306, 0.14705882352941177, 'DiabetesPedigreeFunction <= -0.587\nsquared_error = 0.222\nsamples = 9\nvalue = 0.333'),
#  Text(0.6151419558359621, 0.08823529411764706, 'Age <= 1.079\nsquared_error = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(0.6025236593059937, 0.029411764705882353, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.6277602523659306, 0.029411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.6403785488958991, 0.08823529411764706, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.5772870662460567, 0.2647058823529412, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.6025236593059937, 0.38235294117647056, 'Glucose <= 0.781\nsquared_error = 0.09\nsamples = 10\nvalue = 0.9'),
#  Text(0.5899053627760252, 0.3235294117647059, 'squared_error = 0.0\nsamples = 9\nvalue = 1.0'),
#  Text(0.6151419558359621, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7192429022082019, 0.4411764705882353, 'BMI <= -0.106\nsquared_error = 0.24\nsamples = 35\nvalue = 0.4'),
#  Text(0.6529968454258676, 0.38235294117647056, 'Insulin <= 0.837\nsquared_error = 0.099\nsamples = 9\nvalue = 0.111'),
#  Text(0.6403785488958991, 0.3235294117647059, 'squared_error = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(0.6656151419558359, 0.3235294117647059, 'Glucose <= 0.815\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.6529968454258676, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.6782334384858044, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.7854889589905363, 0.38235294117647056, 'Glucose <= 0.167\nsquared_error = 0.25\nsamples = 26\nvalue = 0.5'),
#  Text(0.7287066246056783, 0.3235294117647059, 'Insulin <= -0.283\nsquared_error = 0.228\nsamples = 17\nvalue = 0.353'),
#  Text(0.7034700315457413, 0.2647058823529412, 'Pregnancies <= 1.565\nsquared_error = 0.222\nsamples = 6\nvalue = 0.667'),
#  Text(0.6908517350157729, 0.20588235294117646, 'SkinThickness <= 0.683\nsquared_error = 0.16\nsamples = 5\nvalue = 0.8'),
#  Text(0.6782334384858044, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7034700315457413, 0.14705882352941177, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.7160883280757098, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7539432176656151, 0.2647058823529412, 'Insulin <= 1.182\nsquared_error = 0.149\nsamples = 11\nvalue = 0.182'),
#  Text(0.7413249211356467, 0.20588235294117646, 'squared_error = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(0.7665615141955836, 0.20588235294117646, 'Age <= 0.615\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.7539432176656151, 0.14705882352941177, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.7791798107255521, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8422712933753943, 0.3235294117647059, 'Insulin <= 2.081\nsquared_error = 0.173\nsamples = 9\nvalue = 0.778'),
#  Text(0.8296529968454258, 0.2647058823529412, 'BMI <= 0.036\nsquared_error = 0.109\nsamples = 8\nvalue = 0.875'),
#  Text(0.8170347003154574, 0.20588235294117646, 'Age <= 0.338\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.804416403785489, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.8296529968454258, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8422712933753943, 0.20588235294117646, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.8548895899053628, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.6624605678233438, 0.5, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.6750788643533123, 0.5588235294117647, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.6876971608832808, 0.6176470588235294, 'squared_error = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(0.804416403785489, 0.6764705882352942, 'BMI <= -0.061\nsquared_error = 0.193\nsamples = 42\nvalue = 0.738'),
#  Text(0.7476340694006309, 0.6176470588235294, 'BMI <= -0.509\nsquared_error = 0.25\nsamples = 14\nvalue = 0.5'),
#  Text(0.722397476340694, 0.5588235294117647, 'BMI <= -0.718\nsquared_error = 0.139\nsamples = 6\nvalue = 0.833'),
#  Text(0.7097791798107256, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7350157728706624, 0.5, 'squared_error = 0.0\nsamples = 5\nvalue = 1.0'),
#  Text(0.7728706624605678, 0.5588235294117647, 'Age <= 0.893\nsquared_error = 0.188\nsamples = 8\nvalue = 0.25'),
#  Text(0.7602523659305994, 0.5, 'squared_error = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(0.7854889589905363, 0.5, 'BMI <= -0.494\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.7728706624605678, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.7981072555205048, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.861198738170347, 0.6176470588235294, 'DiabetesPedigreeFunction <= 2.963\nsquared_error = 0.122\nsamples = 28\nvalue = 0.857'),
#  Text(0.8485804416403786, 0.5588235294117647, 'SkinThickness <= 2.201\nsquared_error = 0.071\nsamples = 26\nvalue = 0.923'),
#  Text(0.8359621451104101, 0.5, 'SkinThickness <= -0.577\nsquared_error = 0.038\nsamples = 25\nvalue = 0.96'),
#  Text(0.8233438485804416, 0.4411764705882353, 'Glucose <= -0.115\nsquared_error = 0.16\nsamples = 5\nvalue = 0.8'),
#  Text(0.8107255520504731, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8359621451104101, 0.38235294117647056, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.8485804416403786, 0.4411764705882353, 'squared_error = 0.0\nsamples = 20\nvalue = 1.0'),
#  Text(0.861198738170347, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8738170347003155, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.8927444794952681, 0.9117647058823529, 'BMI <= -0.517\nsquared_error = 0.124\nsamples = 83\nvalue = 0.855'),
#  Text(0.8359621451104101, 0.8529411764705882, 'Age <= -0.635\nsquared_error = 0.243\nsamples = 12\nvalue = 0.583'),
#  Text(0.8233438485804416, 0.7941176470588235, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.8485804416403786, 0.7941176470588235, 'Age <= 1.958\nsquared_error = 0.173\nsamples = 9\nvalue = 0.778'),
#  Text(0.8359621451104101, 0.7352941176470589, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.861198738170347, 0.7352941176470589, 'Insulin <= 0.173\nsquared_error = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(0.8485804416403786, 0.6764705882352942, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.8738170347003155, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.9495268138801262, 0.8529411764705882, 'DiabetesPedigreeFunction <= -0.47\nsquared_error = 0.089\nsamples = 71\nvalue = 0.901'),
#  Text(0.9242902208201893, 0.7941176470588235, 'Insulin <= 1.704\nsquared_error = 0.168\nsamples = 28\nvalue = 0.786'),
#  Text(0.9116719242902208, 0.7352941176470589, 'DiabetesPedigreeFunction <= -0.535\nsquared_error = 0.151\nsamples = 27\nvalue = 0.815'),
#  Text(0.8990536277602523, 0.6764705882352942, 'Pregnancies <= -0.681\nsquared_error = 0.13\nsamples = 26\nvalue = 0.846'),
#  Text(0.886435331230284, 0.6176470588235294, 'squared_error = 0.0\nsamples = 8\nvalue = 1.0'),
#  Text(0.9116719242902208, 0.6176470588235294, 'DiabetesPedigreeFunction <= -1.156\nsquared_error = 0.173\nsamples = 18\nvalue = 0.778'),
#  Text(0.8990536277602523, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9242902208201893, 0.5588235294117647, 'Glucose <= 1.811\nsquared_error = 0.145\nsamples = 17\nvalue = 0.824'),
#  Text(0.9116719242902208, 0.5, 'squared_error = 0.0\nsamples = 9\nvalue = 1.0'),
#  Text(0.9369085173501577, 0.5, 'Glucose <= 2.043\nsquared_error = 0.234\nsamples = 8\nvalue = 0.625'),
#  Text(0.9242902208201893, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.9495268138801262, 0.4411764705882353, 'Glucose <= 2.425\nsquared_error = 0.139\nsamples = 6\nvalue = 0.833'),
#  Text(0.9369085173501577, 0.38235294117647056, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.9621451104100947, 0.38235294117647056, 'Pregnancies <= -0.2\nsquared_error = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(0.9495268138801262, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.9747634069400631, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9242902208201893, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9369085173501577, 0.7352941176470589, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9747634069400631, 0.7941176470588235, 'Glucose <= 1.446\nsquared_error = 0.023\nsamples = 43\nvalue = 0.977'),
#  Text(0.9621451104100947, 0.7352941176470589, 'Glucose <= 1.412\nsquared_error = 0.09\nsamples = 10\nvalue = 0.9'),
#  Text(0.9495268138801262, 0.6764705882352942, 'squared_error = 0.0\nsamples = 9\nvalue = 1.0'),
#  Text(0.9747634069400631, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9873817034700315, 0.7352941176470589, 'squared_error = 0.0\nsamples = 33\nvalue = 1.0')]

# %% [markdown]
# ### 6.2 Prediction

# %%
Xtest_All = pd.read_csv('../data/processed/SplitData/NormData/All_Xtest_norm.csv')
Xtest_All_Sel = Xtest_All [Xtrain_All_Sel.columns]
ytest_All = pd.read_csv('../data/processed/SplitData/All_ytest.csv')

Xtest_Clean = pd.read_csv('../data/processed/SplitData/NormData/Clean_Xtest_norm.csv')
Xtest_Clean_Sel = Xtest_Clean [Xtrain_Clean_Sel.columns]
ytest_Clean = pd.read_csv('../data/processed/SplitData/Clean_ytest.csv')

# %%
All_ypred = All_model.predict(Xtest_All_Sel)

Clean_ypred = Clean_model.predict(Xtest_Clean_Sel)

# %%
All_MSE = mean_squared_error(ytest_All, All_ypred)
print('MSE with all data:',All_accuracy)

Clean_MSE = mean_squared_error(ytest_Clean, Clean_ypred)
print('MSE with clean data:',Clean_accuracy)
# Out:
# MSE with all data: 0.70995670995671
# MSE with clean data: 0.6883116883116883

# %% [markdown]
# Since, under equal conditions, the most accurate model is the one that uses all the data without replacing the outliers with the chosen metric, we will continue with the optimization of this one.
#
# #### 6.3 Optimization

# %%
from sklearn.model_selection import GridSearchCV

# %%
""" BY DEFAULT
param_grid = {
    'max_depth': [None],
    'max_features': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'criterion': ['squared_error']
}
"""
param_grid = {
    'max_depth': [None,3, 5, 7, 10],
    'max_features': [None,'sqrt', 'log2',5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
}

grid_search = GridSearchCV(estimator=All_model, param_grid=param_grid)
grid_search.fit(Xtrain_All_Sel, ytrain_All)

best_dt_model = grid_search.best_estimator_
dump(best_dt_model, open("../data/processed/Models/GridOptimize_All_model.sav", "wb"))
best_params = grid_search.best_params_
dump(best_dt_model, open("../data/processed/Models/GridOptimize_All_params.sav", "wb"))

y_pred = best_dt_model.predict(Xtest_All_Sel)
mse = mean_squared_error(ytest_All, y_pred)

print("Best parameters:", best_params)
print("MSE:", mse)
# Out:
# Best parameters: {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MSE: 0.2015132415181275
